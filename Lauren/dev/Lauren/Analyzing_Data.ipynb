# %%
#import dependencies
import pandas as pd

# %%
#read in  data
data_df = pd.read_csv("Resources/Clean_Data.csv")

# %%
data_df
# Out:
#        Unnamed: 0 Week-Ending Date  HHS Region  COVID-19 Deaths  \
# 0            4896       2020-01-04           1              0.0
# 1            4897       2020-01-04           1              0.0
# 2            4898       2020-01-04           1              0.0
# 3            4899       2020-01-04           1              0.0
# 4            4900       2020-01-04           1              0.0
# ...           ...              ...         ...              ...
# 42835       53842       2021-04-17          10              0.0
# 42836       53843       2021-04-17          10              NaN
# 42837       53844       2021-04-17          10              NaN
# 42838       53845       2021-04-17          10              NaN
# 42839       53846       2021-04-17          10              NaN
#
#        Race and Hispanic Origin Group_Hispanic  \
# 0                                            1
# 1                                            1
# 2                                            1
# ...
