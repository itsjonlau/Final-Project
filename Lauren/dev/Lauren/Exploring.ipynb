# %%
#import dependencies
import pandas as pd

# %%
#read in vaccination data
deaths_df = pd.read_csv("Resources/Weekly_deaths.csv")
# Out:
# C:\Users\lmsul\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
deaths_df
# Out:
#        Data As Of  Start Date    End Date     Group       Year  Month  \
# 0      04/21/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 1      04/21/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 2      04/21/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 3      04/21/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# 4      04/21/2021  12/29/2019  01/04/2020   By Week  2019/2020    NaN
# ...           ...         ...         ...       ...        ...    ...
# 68899  04/21/2021  01/01/2020  04/17/2021  By Total  2020/2021    NaN
# 68900  04/21/2021  01/01/2020  04/17/2021  By Total  2020/2021    NaN
# 68901  04/21/2021  01/01/2020  04/17/2021  By Total  2020/2021    NaN
# 68902  04/21/2021  01/01/2020  04/17/2021  By Total  2020/2021    NaN
# 68903  04/21/2021  01/01/2020  04/17/2021  By Total  2020/2021    NaN
#
#        MMWR Week Week-Ending Date     HHS Region  \
# 0            1.0       01/04/2020  United States
# ...

# %%
deaths_df.dtypes
# Out:
# Data As Of                         object
# Start Date                         object
# End Date                           object
# Group                              object
# Year                               object
# Month                             float64
# MMWR Week                         float64
# Week-Ending Date                   object
# HHS Region                         object
# Race and Hispanic Origin Group     object
# Age Group                          object
# COVID-19 Deaths                   float64
# Total Deaths                      float64
# Footnote                           object
# dtype: object

# %%
deaths_df.drop(["Data As Of", "Start Date", "End Date", "Year", "Month", "MMWR Week", "Total Deaths", "Footnote"], axis=1)
# Out:
#           Group Week-Ending Date     HHS Region  \
# 0       By Week       01/04/2020  United States
# 1       By Week       01/04/2020  United States
# 2       By Week       01/04/2020  United States
# 3       By Week       01/04/2020  United States
# 4       By Week       01/04/2020  United States
# ...         ...              ...            ...
# 68899  By Total              NaN             10
# 68900  By Total              NaN             10
# 68901  By Total              NaN             10
# 68902  By Total              NaN             10
# 68903  By Total              NaN             10
#
#       Race and Hispanic Origin Group          Age Group  COVID-19 Deaths
# 0                           Hispanic          0-4 years              0.0
# 1                           Hispanic         5-17 years              0.0
# 2                           Hispanic        18-29 years              0.0
# 3                           Hispanic        30-39 years              0.0
# ...

# %%
deaths_df.drop(deaths_df["HHS Region" == "United States"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-c05f5cd51bc9> in <module>
# ...
