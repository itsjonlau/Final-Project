# %%
import pandas as pd 
import os

# %%
#Load Death Group Data 
Deaths_age_group = pd.read_csv("Resources\Provisional_COVID-19_Death_Counts_by_Sex__Age__and_State.csv")
# Out:
# C:\Users\Jon Lau\anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Deaths_age_group
# Out:
#        Data As Of  Start Date    End Date     Group    Year  Month  \
# 0      04/21/2021  01/01/2020  04/17/2021  By Total     NaN    NaN
# 1      04/21/2021  01/01/2020  04/17/2021  By Total     NaN    NaN
# 2      04/21/2021  01/01/2020  04/17/2021  By Total     NaN    NaN
# 3      04/21/2021  01/01/2020  04/17/2021  By Total     NaN    NaN
# 4      04/21/2021  01/01/2020  04/17/2021  By Total     NaN    NaN
# ...           ...         ...         ...       ...     ...    ...
# 52321  04/21/2021  04/01/2021  04/17/2021  By Month  2021.0    4.0
# 52322  04/21/2021  04/01/2021  04/17/2021  By Month  2021.0    4.0
# 52323  04/21/2021  04/01/2021  04/17/2021  By Month  2021.0    4.0
# 52324  04/21/2021  04/01/2021  04/17/2021  By Month  2021.0    4.0
# 52325  04/21/2021  04/01/2021  04/17/2021  By Month  2021.0    4.0
#
#                State        Sex          Age Group COVID-19 Deaths  \
# 0      United States  All Sexes           All Ages         551,728
# ...

# %%
Deaths_age_group.shape
# Out:
# (52326, 16)

# %%
Deaths_age_group.dtypes
# Out:
# Data As Of                                   object
# Start Date                                   object
# End Date                                     object
# Group                                        object
# Year                                        float64
# Month                                       float64
# State                                        object
# Sex                                          object
# Age Group                                    object
# COVID-19 Deaths                              object
# Total Deaths                                 object
# Pneumonia Deaths                             object
# Pneumonia and COVID-19 Deaths                object
# Influenza Deaths                             object
# Pneumonia, Influenza, or COVID-19 Deaths     object
# Footnote                                     object
# dtype: object

# %%
#dropping unused column data
Deaths_age_group.drop(columns =["Data As Of", "Month","Pneumonia Deaths","Influenza Deaths","Footnote","Sex","Year","Group", "Pneumonia, Influenza, or COVID-19 Deaths", "Pneumonia and COVID-19 Deaths", "State", "Total Deaths"], inplace=True)

# %%
Deaths_age_group
# Out:
#        Start Date    End Date          Age Group COVID-19 Deaths
# 0      01/01/2020  04/17/2021           All Ages         551,728
# 1      01/01/2020  04/17/2021       Under 1 year              63
# 2      01/01/2020  04/17/2021         0-17 years             266
# 3      01/01/2020  04/17/2021          1-4 years              31
# 4      01/01/2020  04/17/2021         5-14 years              96
# ...           ...         ...                ...             ...
# 52321  04/01/2021  04/17/2021        50-64 years             NaN
# 52322  04/01/2021  04/17/2021        55-64 years             NaN
# 52323  04/01/2021  04/17/2021        65-74 years             NaN
# 52324  04/01/2021  04/17/2021        75-84 years             NaN
# 52325  04/01/2021  04/17/2021  85 years and over             NaN
#
# [52326 rows x 4 columns]

# %%
#form New Age Groups
groups = { 
    "Newborn-Young Adolescent": ["Under 1 year", "1-4 years", "0-17 years"],
    "Teenager-Young Adults": ["5-14years", "15-24 years", "18-29 years"],
    "Middle-Aged Adults": ["25-34 years", "30-39 years", "35-44 years"],
    "Older Adults": ["40-49 years", "45-54 years", "50-64 years"],
    "Seniors": ["55-64 years", "65-74 years", "85 years and over"],
    "N/A":["All Ages"]
    }

# %%
#applying New Age Groups to data   
Deaths_age_group["New Age"] = (
    Deaths_age_group["Age Group"]
    .apply(lambda x:[a for a in groups.keys() if x in groups[a]])
    .str[0]
    .fillna("Other")
)

#combine data 
new_age_group = Deaths_age_group.groupby(["Start Date","End Date", "COVID-19 Deaths", "New Age"]).sum()
#new_age_group.drop(columns =("Age Group"), axis=1)
#del new_age_group("Age Group")
print(new_age_group) 
#new_age_group.head()
# Out:
#                                                                                                         Age Group
# Start Date End Date   COVID-19 Deaths New Age
# 01/01/2020 01/31/2020 0               Middle-Aged Adults        25-34 years30-39 years35-44 years25-34 years30...
#                                       N/A                       All AgesAll AgesAll AgesAll AgesAll AgesAll Ag...
#                                       Newborn-Young Adolescent  Under 1 year0-17 years1-4 yearsUnder 1 year0-1...
#                                       Older Adults              40-49 years40-49 years45-54 years50-64 years40...
#                                       Other                     5-14 years5-14 years5-14 years75-84 years5-14 ...
# ...                                                                                                           ...
# 12/01/2020 12/31/2020 981             Other                                                75-84 years75-84 years
# ...

# %%
#Export data 
new_age_group.to_csv("C:\\Users\\Jon Lau\\Desktop\\Class\\Final-Project\\Jonlau_Dev\\Resources\\Updated_Data.csv")

# %%
#load Death Weekly Data
Death_age_week = pd.read_csv("Resources\Provisional_COVID-19_Death_Counts_by_Sex__Age__and_Week.csv")

# %%
Death_age_week
# Out:
#       Data as of          State  MMWR Week    End Week      Sex  \
# 0     04/21/2021  United States          1  01/04/2020  All Sex
# 1     04/21/2021  United States          1  01/04/2020  All Sex
# 2     04/21/2021  United States          1  01/04/2020  All Sex
# 3     04/21/2021  United States          1  01/04/2020  All Sex
# 4     04/21/2021  United States          1  01/04/2020  All Sex
# ...          ...            ...        ...         ...      ...
# 2443  04/21/2021  United States         15  04/17/2021   Female
# 2444  04/21/2021  United States         15  04/17/2021   Female
# 2445  04/21/2021  United States         15  04/17/2021   Female
# 2446  04/21/2021  United States         15  04/17/2021   Female
# 2447  04/21/2021  United States         15  04/17/2021   Female
#
#               Age Group Total Deaths COVID-19 Deaths
# 0              All Ages       60,154               0
# 1          Under 1 year          405               0
# ...

# %%
Death_age_week.dtypes
# Out:
# Data as of         object
# State              object
# MMWR Week           int64
# End Week           object
# Sex                object
# Age Group          object
# Total Deaths       object
# COVID-19 Deaths    object
# dtype: object

# %%
#dropping unused column data
Death_age_week.drop(columns =["Data as of", "MMWR Week" , "Sex", "State" ], inplace=True)

# %%
Death_age_week
# Out:
#         End Week          Age Group Total Deaths COVID-19 Deaths
# 0     01/04/2020           All Ages       60,154               0
# 1     01/04/2020       Under 1 year          405               0
# 2     01/04/2020          1-4 Years           79               0
# 3     01/04/2020         5-14 Years           99               0
# 4     01/04/2020        15-24 Years          605               0
# ...          ...                ...          ...             ...
# 2443  04/17/2021        45-54 Years          220              27
# 2444  04/17/2021        55-64 Years          593              65
# 2445  04/17/2021        65-74 Years        1,152             112
# 2446  04/17/2021        75-84 Years        1,731             135
# 2447  04/17/2021  85 Years and Over        2,644             122
#
# [2448 rows x 4 columns]

# %%
#applying Age Groups to week data    
Death_age_week["New Age"] = (
    Death_age_week["Age Group"]
    .apply(lambda x:[a for a in groups.keys() if x in groups[a]])
    .str[0]
)

#combine data 
new_age_week = Death_age_week.groupby(["New Age", "End Week", "COVID-19 Deaths", "Total Deaths"]).sum()
new_age_week.reset_index()
print(new_age_week)
#new_age_week.head()
# Out:
#                                                                      Age Group
# New Age                  End Week   COVID-19 Deaths Total Deaths
# N/A                      01/02/2021 10,844          39,690            All Ages
#                                     13,404          44,852            All Ages
#                                     24,248          84,542            All Ages
#                          01/04/2020 0               29,231            All Ages
#                                                     30,923            All Ages
# ...                                                                        ...
# Newborn-Young Adolescent 12/19/2020 1               180           Under 1 year
#                                                     330           Under 1 year
#                          12/26/2020 1               125           Under 1 year
#                                     2               192           Under 1 year
# ...

# %%
#Export data 
new_age_week.to_csv("C:\\Users\\Jon Lau\\Desktop\\Class\\Final-Project\\Jonlau_Dev\\Resources\\Updated_Data.csv")

# %%
#import Vaccine Data
Pfz_ds = pd.read_csv("Resources\COVID-19_Vaccine_Distribution_Allocations_by_Jurisdiction_-_Pfizer.csv")
MDN_ds = pd.read_csv("Resources\COVID-19_Vaccine_Distribution_Allocations_by_Jurisdiction_-_Moderna.csv")
JnJ_ds = pd.read_csv("Resources\COVID-19_Vaccine_Distribution_Allocations_by_Jurisdiction_-_Janssen.csv")

# %%
Pfz_ds

# %%
MDN_ds

# %%
JnJ_ds

# %%
#Merge and Export data
Pfz_ds.to_csv("C:\\Users\\Jon Lau\\Desktop\\Class\\Final-Project\\Jonlau_Dev\\Resources\\Updated_Data.csv")
MDN_ds.to_csv("C:\\Users\\Jon Lau\\Desktop\\Class\\Final-Project\\Jonlau_Dev\\Resources\\Updated_Data.csv")
JnJ_ds.to_csv("C:\\Users\\Jon Lau\\Desktop\\Class\\Final-Project\\Jonlau_Dev\\Resources\\Updated_Data.csv")
